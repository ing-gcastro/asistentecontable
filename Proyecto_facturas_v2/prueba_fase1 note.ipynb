# %%
# %load_ext autoreload
# %autoreload 2

import os
from datetime import datetime
import pandas as pd
from config import CARPETA_A, CARPETA_C
from procesador_core import iniciar_proceso_interactivo, obtener_ultima_fecha_procesada

# %%
# =======================================================================
# ⚙️ PANEL DE CONTROL VISUAL
# =======================================================================
EJECUTAR_DESCARGA = False     
USAR_FILTRO_FECHA = False
FECHA_INICIO = "04/08/2026"  
FECHA_FIN = ""               
FILTRO_CORREO = ""           
# =======================================================================

ruta_html_reporte = r"\\10.10.10.210\\AyF_Trabajoadistancia\\Compras\\Reporte_Maestro.html"
ultima_fecha_html = obtener_ultima_fecha_procesada(ruta_html_reporte)

print("📊 ESTADO DEL SISTEMA Y ARCHIVOS:")
print(f"   • Última factura registrada en el Reporte HTML: {ultima_fecha_html if ultima_fecha_html else 'Sin registros'}")

if os.path.exists(CARPETA_A):
    archivos_a = [os.path.join(CARPETA_A, f) for f in os.listdir(CARPETA_A) if f.lower().endswith('.pdf')]
    if archivos_a:
        ultimo_archivo_mod = max(archivos_a, key=os.path.getmtime)
        tiempo_mod = datetime.fromtimestamp(os.path.getmtime(ultimo_archivo_mod))
        print(f"   • Último PDF modificado/recibido en Carpeta A: {tiempo_mod.strftime('%d/%m/%Y %H:%M:%S')}")
    else:
        print("   • Carpeta A: Vacía (sin PDFs pendientes).")
else:
    print("   ⚠️ La Carpeta A no existe.")
# Out:
# 📊 ESTADO DEL SISTEMA Y ARCHIVOS:
#    • Última factura registrada en el Reporte HTML: 06/08/2026
#    • Último PDF modificado/recibido en Carpeta A: 05/08/2026 14:03:48

# %%
# Ejecuta todo el proceso interactivo llamando al core
iniciar_proceso_interactivo(
    ejecutar_descarga=EJECUTAR_DESCARGA,
    usar_filtro_fecha=USAR_FILTRO_FECHA,
    fecha_inicio=FECHA_INICIO,
    fecha_fin=FECHA_FIN,
    filtro_correo=FILTRO_CORREO
)
# Out:
# 📅 Rango de búsqueda optimizado desde: 06/08/2026
# 📥 Cargando bases de datos de proveedores y sectores...
# 🛡️ Filtro activo: Se encontraron 36 facturas previas registradas en el historial.
#
# ============================================================
# 📄 Archivo principal: A 26995 TELCOM ANTINA (1).pdf
#    ↳ Proveedor detectado : PROVEEDOR_DESCONOCIDO
#    ↳ CUIT                  :
#    ↳ Fecha Emisión         : 06/08/2026
#    ↳ Tipo y Número         : FC - 26995
#    ↳ Sector                : GENERAL
#    ✨ Nombre Propuesto     : (AGOSTO) PROVEEDOR_DESCONOCIDO FC 26995.pdf
# ============================================================
# ¿Qué deseas hacer?
#   [Enter] ➔ Aprobar y mover a 'fc a subir'
#   [e]     ➔ Editar nombre manualmente
#   [n]     ➔ Rechazar (Mover a 'no es factura')
# Tu opción:  e
# Escribe el nuevo nombre (sin .pdf) o presiona Enter para usar '(AGOSTO) PROVEEDOR_DESCONOCIDO FC 26995.pdf':   (AGOSTO) ERICNET FC 26995 OPERACIONES.pdf
# [DEBUG] Iniciando búsqueda de OCs...
# Buscando OC en BD para: 'PROVEEDOR_DESCONOCIDO' o CUIT 'NO_MATCH_XYZ'
# OCs encontradas en BD para este proveedor: 0
# [DEBUG] OCs devueltas por el manager: 0
# ✅ ¡Aprobado y movido a Carpeta C!
#
# ============================================================
# 📄 Archivo principal: A 26996 TELCOM ANTINA (1).pdf
#    ↳ Proveedor detectado : PROVEEDOR_DESCONOCIDO
#    ↳ CUIT                  :
#    ↳ Fecha Emisión         : 06/08/2026
#    ↳ Tipo y Número         : FC - 26996
#    ↳ Sector                : GENERAL
#    ✨ Nombre Propuesto     : (AGOSTO) PROVEEDOR_DESCONOCIDO FC 26996.pdf
# ============================================================
# ¿Qué deseas hacer?
#   [Enter] ➔ Aprobar y mover a 'fc a subir'
#   [e]     ➔ Editar nombre manualmente
#   [n]     ➔ Rechazar (Mover a 'no es factura')
# Tu opción:  E
# Escribe el nuevo nombre (sin .pdf) o presiona Enter para usar '(AGOSTO) PROVEEDOR_DESCONOCIDO FC 26996.pdf':   (AGOSTO) ERICNET S.A. FC 26996 OPERACIONES.pdf
# [DEBUG] Iniciando búsqueda de OCs...
# Buscando OC en BD para: 'PROVEEDOR_DESCONOCIDO' o CUIT 'NO_MATCH_XYZ'
# OCs encontradas en BD para este proveedor: 0
# [DEBUG] OCs devueltas por el manager: 0
# ✅ ¡Aprobado y movido a Carpeta C!
#
# ============================================================
# 📄 Archivo principal: Factura de venta_WK-A-00004-00005560.pdf
#    ↳ Proveedor detectado : WORKIA S.A.
#    ↳ CUIT                  : 30716051672
#    ↳ Fecha Emisión         : 06/08/2026
#    ↳ Tipo y Número         : FC - 5560
#    ↳ Sector                : RRHH
#    ✨ Nombre Propuesto     : (AGOSTO) WORKIA S.A. FC 5560 RRHH.pdf
# ============================================================
# ¿Qué deseas hacer?
#   [Enter] ➔ Aprobar y mover a 'fc a subir'
#   [e]     ➔ Editar nombre manualmente
#   [n]     ➔ Rechazar (Mover a 'no es factura')
# Tu opción:  E
# Escribe el nuevo nombre (sin .pdf) o presiona Enter para usar '(AGOSTO) WORKIA S.A. FC 5560 RRHH.pdf':  (AGOSTO) WORKIA S.A. FC 5560 RRHH LICENCIA
# [DEBUG] Iniciando búsqueda de OCs...
# Buscando OC en BD para: 'WORKIA' o CUIT '30716051672'
# OCs encontradas en BD para este proveedor: 0
# [DEBUG] OCs devueltas por el manager: 0
# ✅ ¡Aprobado y movido a Carpeta C!
#
# ============================================================
# 📄 Archivo principal: FCA-00004-00000153 (1).pdf
#    ↳ Proveedor detectado : MILLION CONTAINERS S. A.
#    ↳ CUIT                  : 30712194258
#    ↳ Fecha Emisión         :
#    ↳ Tipo y Número         : FC - 153
#    ↳ Sector                : ADM
#    ✨ Nombre Propuesto     : (AGOSTO) MILLION CONTAINERS S. A. FC 153 ADM.pdf
# ============================================================
# ¿Qué deseas hacer?
#   [Enter] ➔ Aprobar y mover a 'fc a subir'
#   [e]     ➔ Editar nombre manualmente
#   [n]     ➔ Rechazar (Mover a 'no es factura')
# Tu opción:
# [DEBUG] Iniciando búsqueda de OCs...
# Buscando OC en BD para: 'MILLION' o CUIT '30712194258'
# OCs encontradas en BD para este proveedor: 0
# [DEBUG] OCs devueltas por el manager: 0
# ✅ ¡Aprobado y movido a Carpeta C!
#
# ============================================================
# 📄 Archivo principal: FCA0003-00087160.pdf
#    ↳ Proveedor detectado : T-COM SA
#    ↳ CUIT                  : 33709046689
#    ↳ Fecha Emisión         : 07/08/2026
#    ↳ Tipo y Número         : FC - 87160
#    ↳ Sector                : OPERACIONES
#    ✨ Nombre Propuesto     : (AGOSTO) T-COM SA FC 87160 OPERACIONES.pdf
# ============================================================
# ¿Qué deseas hacer?
#   [Enter] ➔ Aprobar y mover a 'fc a subir'
#   [e]     ➔ Editar nombre manualmente
#   [n]     ➔ Rechazar (Mover a 'no es factura')
# Tu opción:
# [DEBUG] Iniciando búsqueda de OCs...
# Buscando OC en BD para: 'T-COM' o CUIT '33709046689'
# OCs encontradas en BD para este proveedor: 0
# [DEBUG] OCs devueltas por el manager: 0
# ✅ ¡Aprobado y movido a Carpeta C!
# [-] OrdenPago.pdf -> NO ES FACTURA. Movido automáticamente a Carpeta B.
#
# 🎯 Proceso finalizado. Aprobadas: 5 | Duplicados omitidos: 0
# Reporte acumulativo actualizado con exito en: \\10.10.10.210\AyF_Trabajoadistancia\Compras\Reporte_Maestro.html (Total registros: 42)

# %%
from reporter import generar_reporte_html

print("🔄 Actualizando reporte de 'fc a subir'...")
generar_reporte_html()
# Out:
# 🔄 Actualizando reporte de 'fc a subir'...
# Reporte acumulativo actualizado con exito en: \\10.10.10.210\AyF_Trabajoadistancia\Compras\Reporte_Maestro.html (Total registros: 34)
